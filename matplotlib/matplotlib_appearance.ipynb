# %% [markdown]
# # MATPLOTLIB Appearance

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.5,0.5])
ax.plot(x,y, color='green', ls='--')

#limits
ax.set_xlim([0,1])
ax.set_ylim([0,2])

# %% [markdown]
# ---

# %%
x = np.linspace(-np.pi, np.pi, 256)
c, s = np.cos(x), np.sin(x)

# %%
fig == plt.figure()
plt.plot(x, c, color='blue', lw=2, ls='-', label='cosine')
plt.plot(x, s, color='red', lw=2, ls='-', label='sine')

#img too tight, min max with 110% breathing room
plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.ylim(c.min() * 1.1, c.max() * 1.1)

#X Y ticks
plt.yticks([-1, 0, +1])
# $$ inline LaTeX
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

ax = plt.gca() #get current axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.spines['bottom'].set_position(('data',0)) # 0 sets in middle
ax.spines['left'].set_position(('data',0))

#annotation
plt.legend(loc=0,frameon = False) #remove frame

#annotate axis
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color ='blue', linewidth=1.5, linestyle="--")

plt.annotate(r't point',
             xy=(t, np.cos(t)), #x and y location pf where to point
             xytext=(-90, -50), textcoords='offset points', fontsize=16, #offset pont
             arrowprops=dict(arrowstyle="->", connectionstyle="arc"))
# Out:
# Text(-90, -50, 't point')
