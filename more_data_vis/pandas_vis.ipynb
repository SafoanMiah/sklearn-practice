# %% [markdown]
# # PANDAS BUILT-IN VISUALIZATION
# (based on plt)

# %%
import numpy as np
import seaborn as sns
import pandas as pd

sns.set_style()

df1 = pd.read_csv('df1', index_col=0) #first col is index
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
#plt.style.use('ggplot')

# %%
df1.head(3)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638

# %%
df2.head(3)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510

# %%
df3.head(3)
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758

# %%
df1['A'].hist(bins=30, figsize=(4,3)) #its calling matplotlib under the hood
#when you JUST inport seaborn they look different
# Out:
# <Axes: >

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1.plot.line(y='B', figsize=(12,3), lw=0.5)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B',c='C') #the color is like the HUE, its based on another col
#3D plot

df1.plot.scatter(x='A',y='B',s=df1['C']*50) #show by size instead of color, too small so multiply by factor
# Out:
# e:\Udemy\DS_ML_1\.iris\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.linspace)

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['A', 'B'])
df
# Out:
#             A         B
# 0   -0.145768 -0.794034
# 1    1.798352 -0.056877
# 2    1.083234 -0.118621
# 3    0.560210 -0.473677
# 4    0.166260 -0.188423
# ..        ...       ...
# 995 -0.793147 -1.182399
# 996  0.852113  0.771209
# 997 -0.623652 -1.891886
# 998  2.431318 -1.151882
# 999 -0.931580 -0.106322
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A', y='B', gridsize=25) #hex too small so increase gridsize
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
