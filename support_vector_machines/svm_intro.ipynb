# %% [markdown]
# # Support Vector Machines
#
# #### SVR is for regression
#
# Statitical Learning (Chapter line)
#
# Support vector machines are supervised learning models with associted learning algorithms that analyze data and recognise patterns, used for classificaation and regression analysis
#
# Here we'll use tem for claification
#
# ![image-2.png](attachment:image-2.png)
# - 2 casses blue/pink
# - doing binary classificaion using x/y (feature1/2)
# - intuitevly we can draw a hyperplane, but we have too many options
#
# ![image-3.png](attachment:image-3.png)
# - so we choose the hyperplane that maximised the margin between classes
# - the vector ploints that the lines touch are called support vectors (circled vectors)
#
#
# You can extend this to non linearly seperable data
# ![image.png](attachment:image.png)
# - The first circle is what we actually have and since its inst in format to be able to seperate with just a line we can force view it in a higher dimention
#
# ![image-4.png](attachment:image-4.png)
